# %%
import pandas as pd
import numpy as np

# %%
courses = pd.read_csv("courses.csv")
students = pd.read_csv("students.csv")
month_1 = pd.read_csv("reg-month1.csv")
month_2 = pd.read_csv("reg-month2.csv")

# %%
month_1.head()
# Out:
#    student_id  course_id
# 0          30          1
# 1          15          5
# 2          18          6
# 3          51          4
# 4          16          9

# %%
month_2.head()
# Out:
#    student_id  course_id
# 0          23          5
# 1          16          7
# 2          12         10
# 3          12          1
# 4          17          9

# %%
concatenated_data = pd.concat([month_1,month_2], ignore_index = True)

# %%
concatenated_data
# Out:
#     student_id  course_id
# 0           30          1
# 1           15          5
# 2           18          6
# 3           51          4
# 4           16          9
# 5           18          1
# 6           45          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12          43         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          18          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25          23          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          17          9
# 30          14          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
students.head()
# Out:
#    student_id          name  partner
# 0           1  Sylas Halder       23
# 1           2        Shafiq        1
# 2           3         Rafiq        3
# 3           4         Karim       14
# 4           5     Saifullah        6

# %%
courses.head()
# Out:
#    course_id       course_name  price
# 0          1            python   2499
# 1          2            pandas   3499
# 2          3     data analysis   4999
# 3          4  machine learning   9999
# 4          5             Numpy   2499

# %%
students.merge(concatenated_data,how="inner", on = "student_id")
# Out:
#     student_id          name  partner  course_id
# 0            1  Sylas Halder       23          6
# 1            1  Sylas Halder       23         10
# 2            1  Sylas Halder       23          9
# 3            3         Rafiq        3          3
# 4            7          Antu        9          8
# 5            7          Antu        9          2
# 6           11         Jafor       20          7
# 7           11         Jafor       20          8
# 8           11         Jafor       20         10
# 9           12         Feroj       19         10
# 10          12         Feroj       19          1
# 11          12         Feroj       19          5
# 12          12         Feroj       19          7
# 13          13         Mizan       24          3
# 14          14       Sahadat       22          7
# 15          14       Sahadat       22          6
# 16          14       Sahadat       22          4
# 17          14       Sahadat       22          1
# ...

# %%
students.merge(concatenated_data,how="left", on = "student_id")
# Out:
#     student_id          name  partner  course_id
# 0            1  Sylas Halder       23        6.0
# 1            1  Sylas Halder       23       10.0
# 2            1  Sylas Halder       23        9.0
# 3            2        Shafiq        1        NaN
# 4            3         Rafiq        3        3.0
# 5            4         Karim       14        NaN
# 6            5     Saifullah        6        NaN
# 7            6        Khalid       10        NaN
# 8            7          Antu        9        8.0
# 9            7          Antu        9        2.0
# 10           8         Samol        5        NaN
# 11           9        Asraf         4        NaN
# 12          10         Rahul        8        NaN
# 13          11         Jafor       20        7.0
# 14          11         Jafor       20        8.0
# 15          11         Jafor       20       10.0
# 16          12         Feroj       19       10.0
# 17          12         Feroj       19        1.0
# ...

# %%
left_data = {"student_id": [1,2,3,4],
             "name": ["sylas", "Karim", "Mohobbat", "Priya"]}

left_df = pd.DataFrame(left_data)

# %%
left_df
# Out:
#    student_id      name
# 0           1     sylas
# 1           2     Karim
# 2           3  Mohobbat
# 3           4     Priya

# %%
right_data = {"student_id": [1,3,5],
             "score": [90,85,75]}

right_df = pd.DataFrame(right_data)

# %%
right_df
# Out:
#    student_id  score
# 0           1     90
# 1           3     85
# 2           5     75

# %%
result_right_join = pd.merge(left_df,right_df, how="right", on = "student_id")

# %%
result_right_join
# Out:
#    student_id      name  score
# 0           1     sylas     90
# 1           3  Mohobbat     85
# 2           5       NaN     75

# %%
result_right_join = pd.merge(left_df,right_df, how="left", on = "student_id")

# %%
result_right_join
# Out:
#    student_id      name  score
# 0           1     sylas   90.0
# 1           2     Karim    NaN
# 2           3  Mohobbat   85.0
# 3           4     Priya    NaN

# %%
result_right_join = pd.merge(left_df,right_df, how="outer", on = "student_id")

# %%
result_right_join
# Out:
#    student_id      name  score
# 0           1     sylas   90.0
# 1           2     Karim    NaN
# 2           3  Mohobbat   85.0
# 3           4     Priya    NaN
# 4           5       NaN   75.0

# %%
result_right_join = pd.merge(left_df,right_df, how='cross')

# %%
result_right_join
# Out:
#     student_id_x      name  student_id_y  score
# 0              1     sylas             1     90
# 1              1     sylas             3     85
# 2              1     sylas             5     75
# 3              2     Karim             1     90
# 4              2     Karim             3     85
# 5              2     Karim             5     75
# 6              3  Mohobbat             1     90
# 7              3  Mohobbat             3     85
# 8              3  Mohobbat             5     75
# 9              4     Priya             1     90
# 10             4     Priya             3     85
# 11             4     Priya             5     75

# %%
concatenated_data.merge(courses,on = "course_id").groupby("course_name")["price"].sum().plot(kind = "pie")
# Out:
# <Axes: ylabel='price'>
